# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /home/addinedu/yolo_ws/src/train

# %%
from IPython import display
display.clear_output()
from IPython.display import display, Image

import ultralytics
ultralytics.checks()
from ultralytics import YOLO
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.3 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7806MiB)
# Setup complete ✅ (16 CPUs, 31.1 GB RAM, 267.2/914.8 GB disk)

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets
# Out:
# /home/addinedu/yolo_ws/src/train/datasets

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="mNhgPf46t2E2rDQCZ3T0")
project = rf.workspace("roboflow-1n0gn").project("bolts-vroia")
version = project.version(1)
dataset = version.download("yolov8-obb")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in bolts-1 to yolov8-obb:: 100%|██████████| 3448/3448 [00:01<00:00, 2246.88it/s]
# Extracting Dataset Version Zip to bolts-1 in yolov8-obb:: 100%|██████████| 192/192 [00:00<00:00, 3631.37it/s]

# %%
# %cd {HOME}

# !yolo task=obb mode=train model=yolov8s-obb.pt data={dataset.location}/data.yaml epochs=35 imgsz=640 batch=8
# Out:
# /home/addinedu/yolo_ws/src/train
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s-obb.pt to 'yolov8s-obb.pt': 100% ━━━━━━━━━━━━ 22.2MB 15.3MB/s 1.5s.4s<0.4sss
# Ultralytics 8.4.14 🚀 Python-3.12.3 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7806MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/addinedu/yolo_ws/src/train/datasets/bolts-1/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=35, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s-obb.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/addinedu/yolo_ws/src/train/runs/obb/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=obb, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/home/addinedu/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 13.2MB/s 0.1s
# Overriding model.yaml nc=15 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2402614  ultralytics.nn.modules.head.OBB              [1, 1, 16, None, [128, 256, 512]]
# YOLOv8s-obb summary: 145 layers, 11,422,166 parameters, 11,422,150 gradients, 29.6 GFLOPs
#
# Transferred 391/397 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 12.5MB/s 0.4s.3s<0.2s.2s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2688.7±1091.2 MB/s, size: 38.1 KB)
# train: Scanning /home/addinedu/yolo_ws/src/train/datasets/bolts-1/train/labels... 85 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 85/85 2.4Kit/s 0.0s
# train: New cache created: /home/addinedu/yolo_ws/src/train/datasets/bolts-1/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 742.1±535.1 MB/s, size: 40.5 KB)
# val: Scanning /home/addinedu/yolo_ws/src/train/datasets/bolts-1/valid/labels... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 660.8it/s 0.0s
# val: New cache created: /home/addinedu/yolo_ws/src/train/datasets/bolts-1/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 63 weight(decay=0.0), 73 weight(decay=0.0005), 72 bias(decay=0.0)
# Plotting labels to /home/addinedu/yolo_ws/src/train/runs/obb/train/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/addinedu/yolo_ws/src/train/runs/obb/train
# Starting training for 35 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#        1/35      1.98G      1.297      2.226      2.934      0.116         24        640: 100% ━━━━━━━━━━━━ 11/11 3.5it/s 3.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 9.2it/s 0.1s
#                    all          4         12      0.988          1      0.995      0.822
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#        2/35      1.99G      1.068      1.271        2.3    0.09324         38        640: 100% ━━━━━━━━━━━━ 11/11 9.9it/s 1.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 31.7it/s 0.0s
#                    all          4         12      0.798          1      0.989      0.812
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#        3/35         2G      1.082      1.083       2.08    0.08693         24        640: 100% ━━━━━━━━━━━━ 11/11 9.8it/s 1.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 31.1it/s 0.0s
#                    all          4         12      0.987          1      0.995      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#        4/35         2G     0.9505     0.9588      2.032    0.07218         30        640: 100% ━━━━━━━━━━━━ 11/11 10.2it/s 1.1s.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 31.7it/s 0.0s
#                    all          4         12      0.996          1      0.995      0.877
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#        5/35         2G      1.005     0.9347          2    0.05435         23        640: 100% ━━━━━━━━━━━━ 11/11 10.1it/s 1.1s2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 31.7it/s 0.0s
#                    all          4         12      0.996          1      0.995      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
0.968
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#       23/35         2G     0.6437     0.5078      1.494    0.03938         37        640: 100% ━━━━━━━━━━━━ 11/11 10.3it/s 1.1s.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 32.4it/s 0.0s
#                    all          4         12          1          1      0.995      0.969
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#       24/35         2G     0.6801     0.5501      1.515    0.03602         29        640: 100% ━━━━━━━━━━━━ 11/11 10.4it/s 1.1s2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 32.3it/s 0.0s
#                    all          4         12          1          1      0.995      0.962
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#       25/35         2G     0.6695      0.551      1.501     0.0337         14        640: 100% ━━━━━━━━━━━━ 11/11 10.3it/s 1.1s.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 31.2it/s 0.0s
#                    all          4         12      0.996          1      0.995      0.947
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#       26/35         2G     0.4641     0.4313      1.492    0.02628         15        640: 100% ━━━━━━━━━━━━ 11/11 8.4it/s 1.3s.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 32.1it/s 0.0s
#                    all          4         12      0.996          1      0.995      0.947
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#       27/35         2G     0.4517     0.4243      1.459    0.03028         15        640: 100% ━━━━━━━━━━━━ 11/11 10.3it/s 1.1s2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 26.3it/s 0.0s
#                    all          4         12      0.996          1      0.995      0.948
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#       28/35         2G     0.4308     0.3958      1.394    0.02036         15        640: 100% ━━━━━━━━━━━━ 11/11 10.3it/s 1.1s2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 32.0it/s 0.0s
#                    all          4         12      0.996          1      0.995      0.977
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#       29/35         2G     0.3876     0.3785      1.335    0.02657         15        640: 100% ━━━━━━━━━━━━ 11/11 10.4it/s 1.1s.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 26.9it/s 0.0s
#                    all          4         12          1          1      0.995      0.986
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#       30/35         2G      0.381     0.3499      1.283     0.0241         15        640: 100% ━━━━━━━━━━━━ 11/11 10.4it/s 1.1s2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 25.1it/s 0.0s
#                    all          4         12          1          1      0.995       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#       31/35         2G     0.4368     0.3849       1.38    0.02728         15        640: 100% ━━━━━━━━━━━━ 11/11 10.2it/s 1.1s.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 31.8it/s 0.0s
#                    all          4         12          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#       32/35         2G     0.3897      0.354      1.293    0.02197         15        640: 100% ━━━━━━━━━━━━ 11/11 10.3it/s 1.1s.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 32.2it/s 0.0s
#                    all          4         12          1          1      0.995      0.987
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#       33/35         2G     0.4023     0.3671       1.34    0.02309         15        640: 100% ━━━━━━━━━━━━ 11/11 10.2it/s 1.1s.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 31.8it/s 0.0s
#                    all          4         12          1          1      0.995       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#       34/35         2G     0.3839     0.3524      1.321    0.01975         15        640: 100% ━━━━━━━━━━━━ 11/11 10.3it/s 1.1s2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 30.4it/s 0.0s
#                    all          4         12          1          1      0.995       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss angle_loss  Instances       Size
#       35/35         2G     0.3827     0.3523      1.345    0.02506         15        640: 100% ━━━━━━━━━━━━ 11/11 10.2it/s 1.1s2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 30.1it/s 0.0s
#                    all          4         12          1          1      0.995       0.99
#
# 35 epochs completed in 0.014 hours.
# Optimizer stripped from /home/addinedu/yolo_ws/src/train/runs/obb/train/weights/last.pt, 23.2MB
# Optimizer stripped from /home/addinedu/yolo_ws/src/train/runs/obb/train/weights/best.pt, 23.2MB
#
# Validating /home/addinedu/yolo_ws/src/train/runs/obb/train/weights/best.pt...
# Ultralytics 8.4.14 🚀 Python-3.12.3 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7806MiB)
# YOLOv8s-obb summary (fused): 82 layers, 11,411,958 parameters, 0 gradients, 29.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 34.1it/s 0.0s
#                    all          4         12          1          1      0.995      0.995
# Speed: 0.9ms preprocess, 3.0ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /home/addinedu/yolo_ws/src/train/runs/obb/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/obb/train/confusion_matrix.png', width=600)
# Out:
# /home/addinedu/yolo_ws/src/train

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/obb/train/results.png', width=600)
# Out:
# /home/addinedu/yolo_ws/src/train

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/obb/train/val_batch0_pred.jpg', width=600)
# Out:
# /home/addinedu/yolo_ws/src/train
