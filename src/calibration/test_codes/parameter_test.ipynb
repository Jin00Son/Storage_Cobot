# %%
import cv2
import cv2.aruco as aruco
import numpy as np
import threading
import os
import time
import math
import datetime
from scipy.spatial.transform import Rotation as R


from pymycobot.mycobot280 import MyCobot280

# %%
mc = MyCobot280('/dev/ttyUSB1', 1000000)
mc.send_angles([0,0,0,0,0,0], 30)
print(mc.get_coords())
# Out:
# [51.2, -64.1, 409.3, -91.67, 0.7, -89.49]

# %%
mc.release_all_servos()
# Out:
# -1

# %%
mc.focus_all_servos()
# Out:
# -1

# %%
mc.get_coords()
# Out:
# [51.2, -64.2, 409.3, -91.67, 0.7, -89.58]
